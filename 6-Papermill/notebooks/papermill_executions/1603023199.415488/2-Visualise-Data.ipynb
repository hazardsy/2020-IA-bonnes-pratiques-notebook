# %%
import sys

sys.path.append("..")

# %%
import json

import numpy as np

# %%
from source.Visualisation import get_training_data_visualisation

# %% [markdown]
# # Lire la donnée

# %%
with open("../data/processed/iris_visualisation_data.json", "r") as f:
    data = json.load(f)

# %% [markdown]
# # Visualisation

# %%
X = np.array(data.get("X"))
y = np.array(data.get("y"))
feature_names = data.get("feature_names")
class_names = data.get("names")

# %%
get_training_data_visualisation(X, y, class_names, feature_names)
